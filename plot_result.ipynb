# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the data from the CSV file
#result_paper = pd.read_csv('result_paper.csv')
result_j = pd.read_csv('result_j.csv')
result_rs = pd.read_csv('result_rs.csv')

# Plot the data

# %%
# Read the data from the CSV file
result_size_paper = pd.read_csv('result_size_paper.csv')
result_size_j = pd.read_csv('result_size_j.csv')
result_size_rs = pd.read_csv('result_size_rs.csv')

result_size_j.head()
# Out:
#   Graph Name   Max Ref Count   Compression Window   Graph Size   Offset Size
# 0    uk-2002              -1                    1        78.25         18.81
# 1    uk-2002               1                    1       110.02         20.81
# 2    uk-2002               3                    1        93.09         19.74
# 3    uk-2002              -1                    3        69.27         18.20
# 4    uk-2002               1                    3        94.87         20.04

# %%
result_size_paper.head()
# Out:
#                R  Graph Size (MiB) Offset-Array Size (MiB) Seq.  \
# 0              ∞              79.0                            -
# 1              3             106.6                            -
# 2              1             122.9                            -
# 3  ∞ (Transpose)              70.3                            -
# 4  3 (Transpose)              74.6                            -
#
#    Offset-Array Size (MiB) J=1  Offset-Array Size (MiB) J=2  \
# 0                        141.3                         70.7
# 1                        141.3                         70.7
# 2                        141.3                         70.7
# 3                        141.3                         70.7
# 4                        141.3                         70.7
#
#    Offset-Array Size (MiB) J=4  Link Access Time (ns) Seq.  \
# 0                         35.3                         198
# 1                         35.3                         206
# ...
